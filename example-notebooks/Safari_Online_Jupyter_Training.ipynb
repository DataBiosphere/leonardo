# %% [markdown]
# # Jupyter Analysis

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

# %%
ls
# Out:
# CDCChronicDiseaseIndicatorsArthritisDataset.csv
# CDC_Chronic_Disease_Indicators_CDI_Analysis_US.ipynb
# Chronic_Disease_Indicators_CDI_US.csv
# JupyterTrainingWarmUp.ipynb

# %%
# !conda list
# Out:
# # packages in environment at /anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0            py36h2fc01ae_0
# alabaster                 0.7.10           py36h174008c_0
# anaconda                  5.1.0                    py36_2
# anaconda-client           1.6.9                    py36_0
# anaconda-navigator        1.7.0                    py36_0
# anaconda-project          0.8.2            py36h9ee5d53_0
# appnope                   0.1.0            py36hf537a9a_0
# appscript                 1.0.1            py36h9e71e49_1
# asn1crypto                0.24.0                   py36_0
# astroid                   1.6.1                    py36_0
# astropy                   2.0.3            py36h1de35cc_0
# attrs                     17.4.0                   py36_0
# babel                     2.5.3                    py36_0
# backports                 1.0              py36ha3c1827_1
# backports.shutil_get_terminal_size 1.0.0            py36hd7a2ee4_2
# beautifulsoup4            4.6.0            py36h72d3c9f_1
# bitarray                  0.8.1            py36h1de35cc_1
# bkcharts                  0.2              py36h073222e_0
# blaze                     0.11.3           py36h02e7a37_0
# bleach                    2.1.2                    py36_0
# bokeh                     0.12.13          py36h2f9c1c0_0
# boto                      2.48.0           py36hdbc59ac_1
# bottleneck                1.2.1            py36hbd380ad_0
# bzip2                     1.0.6                hd86a083_4
# ca-certificates           2017.08.26           ha1e5d58_0
# certifi                   2018.1.18                py36_0
# cffi                      1.11.4           py36h342bebf_0
# chardet                   3.0.4            py36h96c241c_1
# click                     6.7              py36hec950be_0
# cloudpickle               0.5.2                    py36_1
# clyent                    1.2.2            py36hae3ad88_0
# colorama                  0.3.9            py36hd29a30c_0
# conda                     4.4.10                   py36_0
# conda-build               3.4.1                    py36_0
# conda-env                 2.6.0                h36134e3_0
# conda-verify              2.0.0            py36he837df3_0
# contextlib2               0.5.5            py36hd66e5e7_0
# cryptography              2.1.4            py36h842514c_0
# curl                      7.58.0               ha441bb4_0
# cycler                    0.10.0           py36hfc81398_0
# cython                    0.27.3           py36h6ecb376_0
# cytoolz                   0.9.0            py36h1de35cc_0
# dask                      0.16.1                   py36_0
# dask-core                 0.16.1                   py36_0
# datashape                 0.5.4            py36hfb22df8_0
# dbus                      1.12.2               h5243cc1_1
# decorator                 4.2.1                    py36_0
# distributed               1.20.2                   py36_0
# docutils                  0.14             py36hbfde631_0
# entrypoints               0.2.3            py36hd81d71f_2
# et_xmlfile                1.0.1            py36h1315bdc_0
# expat                     2.2.5                hb8e80ba_0
# fastcache                 1.0.2            py36h1de35cc_2
# filelock                  2.0.13           py36hf9de95b_0
# flask                     0.12.2           py36h5658096_0
# flask-cors                3.0.3            py36h7387b97_0
# freetype                  2.8                  h12048fb_1
# get_terminal_size         1.0.0                h7520d66_0
# gettext                   0.19.8.1             h15daf44_3
# gevent                    1.2.2            py36ha70b9d6_0
# glib                      2.53.6               h33f6a65_2
# glob2                     0.6              py36h94c9186_0
# gmp                       6.1.2                hb37e062_1
# gmpy2                     2.0.8            py36hf9c35bd_2
# greenlet                  0.4.12           py36hf09ba7b_0
# h5py                      2.7.1            py36h39cdac5_0
# hdf5                      1.10.1               ha036c08_1
# heapdict                  1.0.0                    py36_2
# html5lib                  1.0.1            py36h2f9c1c0_0
# icu                       58.2                 h4b95b61_1
# idna                      2.6              py36h8628d0a_1
# imageio                   2.2.0            py36h5e01289_0
# imagesize                 0.7.1            py36h3495948_0
# intel-openmp              2018.0.0             h8158457_8
# ipykernel                 4.8.0                    py36_0
# ipython                   6.2.1            py36h3dda519_1
# ipython_genutils          0.2.0            py36h241746c_0
# ipywidgets                7.1.1                    py36_0
# isort                     4.2.15           py36hceb2a01_0
# itsdangerous              0.24             py36h49fbb8d_1
# jbig                      2.1                  h4d881f8_0
# jdcal                     1.3              py36h1986823_0
# jedi                      0.11.1                   py36_0
# jinja2                    2.10             py36hd36f9c5_0
# jpeg                      9b                   he5867d9_2
# jsonschema                2.6.0            py36hb385e00_0
# jupyter                   1.0.0                    py36_4
# jupyter_client            5.2.2                    py36_0
# jupyter_console           5.2.0            py36hccf5b1c_1
# jupyter_core              4.4.0            py36h79cf704_0
# jupyterlab                0.31.5                   py36_0
# jupyterlab_launcher       0.10.2                   py36_0
# lazy-object-proxy         1.3.1            py36h2fbbe47_0
# libcurl                   7.58.0               hf30b1f0_0
# libcxx                    4.0.1                h579ed51_0
# libcxxabi                 4.0.1                hebd6815_0
# libedit                   3.1                  hb4e282d_0
# libffi                    3.2.1                h475c297_4
# libgfortran               3.0.1                h93005f0_2
# libiconv                  1.15                 hdd342a3_7
# libpng                    1.6.34               he12f830_0
# libsodium                 1.0.15               hd9e47c5_0
# libssh2                   1.8.0                h322a93b_4
# libtiff                   4.0.9                h0dac147_0
# libxml2                   2.9.7                hab757c2_0
# libxslt                   1.1.32               hb819dd2_0
# llvmlite                  0.21.0           py36hff739e7_0
# locket                    0.2.0            py36hca03003_1
# lxml                      4.1.1            py36hef8c89e_1
# lzo                       2.10                 h362108e_2
# markupsafe                1.0              py36h3a1e703_1
# matplotlib                2.1.2            py36h6d6146d_0
# mccabe                    0.6.1            py36hdaeb55d_0
# mistune                   0.8.3                    py36_0
# mkl                       2018.0.1             hfbd8650_4
# mkl-service               1.1.2            py36h7ea6df4_4
# mpc                       1.0.3                h7a72875_5
# mpfr                      3.1.5                h711e7fd_2
# mpmath                    1.0.0            py36hf1b8295_2
# msgpack-python            0.5.1            py36h04f5b5a_0
# multipledispatch          0.4.9            py36hc5f92b5_0
# navigator-updater         0.1.0            py36h7aee5fb_0
# nbconvert                 5.3.1            py36h810822e_0
# nbformat                  4.4.0            py36h827af21_0
# ncurses                   6.0                  hd04f020_2
# networkx                  2.1                      py36_0
# nltk                      3.2.5            py36h1190bce_0
# nose                      1.3.7            py36h73fae2b_2
# notebook                  5.4.0                    py36_0
# numba                     0.36.2          np114py36hc2f221f_0
# numexpr                   2.6.4            py36habcfcfe_0
# numpy                     1.14.0           py36h8a80b8c_1
# numpydoc                  0.7.0            py36he54d08e_0
# odo                       0.5.1            py36hc1af34a_0
# olefile                   0.45.1                   py36_0
# openpyxl                  2.4.10                   py36_0
# openssl                   1.0.2n               hdbc3d79_0
# packaging                 16.8             py36he5e8135_0
# pandas                    0.22.0           py36h0a44026_0
# pandoc                    1.19.2.1             ha5e8f32_1
# pandocfilters             1.4.2            py36h3b0b094_1
# parso                     0.1.1            py36hc90e01c_0
# partd                     0.3.8            py36hf5c4cb8_0
# path.py                   10.5             py36h7bcb313_0
# pathlib2                  2.3.0            py36h877a6d8_0
# patsy                     0.5.0                    py36_0
# pcre                      8.41                 hfb6ab37_1
# pep8                      1.7.1                    py36_0
# pexpect                   4.3.1                    py36_0
# pickleshare               0.7.4            py36hf512f8e_0
# pillow                    5.0.0            py36hfcce615_0
# pip                       9.0.1            py36h1555ced_4
# pkginfo                   1.4.1            py36h25bf955_0
# pluggy                    0.6.0            py36hb1d0581_0
# ply                       3.10             py36h10e714e_0
# prompt_toolkit            1.0.15           py36haeda067_0
# psutil                    5.4.3            py36h1de35cc_0
# ptyprocess                0.5.2            py36he6521c3_0
# py                        1.5.2            py36ha69170d_0
# pycodestyle               2.3.1            py36h83e8646_0
# pycosat                   0.6.3            py36hee92d8f_0
# pycparser                 2.18             py36h724b2fc_1
# pycrypto                  2.6.1            py36h1de35cc_7
# pycurl                    7.43.0.1         py36hdbc3d79_0
# pyflakes                  1.6.0            py36hea45e83_0
# pygments                  2.2.0            py36h240cd3f_0
# pylint                    1.8.2                    py36_0
# pyodbc                    4.0.22           py36h0a44026_0
# pyopenssl                 17.5.0           py36h51e4350_0
# pyparsing                 2.2.0            py36hb281f35_0
# pyqt                      5.6.0            py36he5c6137_6
# pysocks                   1.6.7            py36hfa33cec_1
# pytables                  3.4.2            py36hfbd7ab0_2
# pytest                    3.3.2                    py36_0
# python                    3.6.4                hc167b69_1
# python-dateutil           2.6.1            py36h86d2abb_1
# python.app                2                py36h54569d5_7
# pytz                      2017.3           py36hf0bf824_0
# pywavelets                0.5.2            py36h2710a04_0
# pyyaml                    3.12             py36h2ba1e63_1
# pyzmq                     16.0.3           py36he48b5ad_0
# qt                        5.6.2               h9975529_14
# qtawesome                 0.4.4            py36h468c6fb_0
# qtconsole                 4.3.1            py36hd96c0ff_0
# qtpy                      1.3.1            py36h16bb863_0
# readline                  7.0                  hc1231fa_4
# requests                  2.18.4           py36h4516966_1
# rope                      0.10.7           py36h68959ac_0
# ruamel_yaml               0.15.35          py36h1de35cc_1
# scikit-image              0.13.1           py36h1de35cc_1
# scikit-learn              0.19.1           py36hffbff8c_0
# scipy                     1.0.0            py36h1de22e9_0
# seaborn                   0.8.1            py36h595ecd9_0
# send2trash                1.4.2                    py36_0
# setuptools                38.4.0                   py36_0
# simplegeneric             0.8.1                    py36_2
# singledispatch            3.4.0.3          py36hf20db9d_0
# sip                       4.18.1           py36h2824476_2
# six                       1.11.0           py36h0e22d5e_1
# snowballstemmer           1.2.1            py36h6c7b616_0
# sortedcollections         0.5.3            py36he9c3ed6_0
# sortedcontainers          1.5.9                    py36_0
# sphinx                    1.6.6                    py36_0
# sphinxcontrib             1.0              py36h9364dc8_1
# sphinxcontrib-websupport  1.0.1            py36h92f4a7a_1
# spyder                    3.2.6                    py36_0
# sqlalchemy                1.2.1            py36h1de35cc_0
# sqlite                    3.22.0               h3efe00b_0
# statsmodels               0.8.0            py36h9c68fc9_0
# sympy                     1.1.1            py36h7f3cf04_0
# tblib                     1.3.2            py36hda67792_0
# terminado                 0.8.1                    py36_1
# testpath                  0.3.1            py36h625a49b_0
# tk                        8.6.7                h35a86e2_3
# toolz                     0.9.0                    py36_0
# tornado                   4.5.3                    py36_0
# traitlets                 4.3.2            py36h65bd3ce_0
# typing                    3.6.2            py36haa2d9ef_0
# unicodecsv                0.14.1           py36he531d66_0
# unixodbc                  2.3.4                h4cb4dde_1
# urllib3                   1.22             py36h68b9469_0
# wcwidth                   0.1.7            py36h8c6ec74_0
# webencodings              0.5.1            py36h3b9701d_1
# werkzeug                  0.14.1                   py36_0
# wheel                     0.30.0           py36h5eb2c71_1
# widgetsnbextension        3.1.0                    py36_0
# wrapt                     1.10.11          py36hc29e774_0
# xlrd                      1.1.0            py36h336f4a2_1
# xlsxwriter                1.0.2            py36h3736301_0
# xlwings                   0.11.5                   py36_0
# xlwt                      1.2.0            py36h5ad1178_0
# xz                        5.2.3                h0278029_2
# yaml                      0.1.7                hc338f04_2
# zeromq                    4.2.2                ha360ad0_2
# zict                      0.1.3            py36h71da714_0
# zlib                      1.2.11               hf3cbc9b_2

# %%
df_cdi = pd.read_csv('Chronic_Disease_Indicators_CDI_US.csv', encoding = 'latin1')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (7,10,18,19,20,21,23,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_cdi.head()
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
# 2       2016     2016           AK         Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ        Arizona      BRFSS  Alcohol
# 4       2016     2016           AR       Arkansas      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType        ...        LocationID  TopicID QuestionID  \
# 0  Crude Prevalence        ...                59      ALC     ALC2_2
# 1  Crude Prevalence        ...                 1      ALC     ALC2_2
# 2  Crude Prevalence        ...                 2      ALC     ALC2_2
# 3  Crude Prevalence        ...                 4      ALC     ALC2_2
# 4  Crude Prevalence        ...                 5      ALC     ALC2_2
#
#   DataValueTypeID  StratificationCategoryID1  StratificationID1  \
# 0         CrdPrev                    OVERALL                OVR
# 1         CrdPrev                    OVERALL                OVR
# 2         CrdPrev                    OVERALL                OVR
# 3         CrdPrev                    OVERALL                OVR
# 4         CrdPrev                    OVERALL                OVR
#
#   StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                       NaN               NaN                       NaN
# 1                       NaN               NaN                       NaN
# 2                       NaN               NaN                       NaN
# 3                       NaN               NaN                       NaN
# 4                       NaN               NaN                       NaN
#
#   StratificationID3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 34 columns]

# %%
df_cdi.shape
# Out:
# (523486, 34)

# %%
df_cdi.head(10)
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource    Topic  \
# 0       2016     2016           US         United States      BRFSS  Alcohol
# 1       2016     2016           AL               Alabama      BRFSS  Alcohol
# 2       2016     2016           AK                Alaska      BRFSS  Alcohol
# 3       2016     2016           AZ               Arizona      BRFSS  Alcohol
# 4       2016     2016           AR              Arkansas      BRFSS  Alcohol
# 5       2016     2016           CA            California      BRFSS  Alcohol
# 6       2016     2016           CO              Colorado      BRFSS  Alcohol
# 7       2016     2016           CT           Connecticut      BRFSS  Alcohol
# 8       2016     2016           DE              Delaware      BRFSS  Alcohol
# 9       2016     2016           DC  District of Columbia      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
# 2  Binge drinking prevalence among adults aged >=...      NaN             %
# 3  Binge drinking prevalence among adults aged >=...      NaN             %
# 4  Binge drinking prevalence among adults aged >=...      NaN             %
# 5  Binge drinking prevalence among adults aged >=...      NaN             %
# 6  Binge drinking prevalence among adults aged >=...      NaN             %
# 7  Binge drinking prevalence among adults aged >=...      NaN             %
# 8  Binge drinking prevalence among adults aged >=...      NaN             %
# 9  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType        ...        LocationID  TopicID QuestionID  \
# 0  Crude Prevalence        ...                59      ALC     ALC2_2
# 1  Crude Prevalence        ...                 1      ALC     ALC2_2
# 2  Crude Prevalence        ...                 2      ALC     ALC2_2
# 3  Crude Prevalence        ...                 4      ALC     ALC2_2
# 4  Crude Prevalence        ...                 5      ALC     ALC2_2
# 5  Crude Prevalence        ...                 6      ALC     ALC2_2
# 6  Crude Prevalence        ...                 8      ALC     ALC2_2
# 7  Crude Prevalence        ...                 9      ALC     ALC2_2
# 8  Crude Prevalence        ...                10      ALC     ALC2_2
# 9  Crude Prevalence        ...                11      ALC     ALC2_2
#
#   DataValueTypeID  StratificationCategoryID1  StratificationID1  \
# 0         CrdPrev                    OVERALL                OVR
# 1         CrdPrev                    OVERALL                OVR
# 2         CrdPrev                    OVERALL                OVR
# 3         CrdPrev                    OVERALL                OVR
# 4         CrdPrev                    OVERALL                OVR
# 5         CrdPrev                    OVERALL                OVR
# 6         CrdPrev                    OVERALL                OVR
# 7         CrdPrev                    OVERALL                OVR
# 8         CrdPrev                    OVERALL                OVR
# 9         CrdPrev                    OVERALL                OVR
#
#   StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                       NaN               NaN                       NaN
# 1                       NaN               NaN                       NaN
# 2                       NaN               NaN                       NaN
# 3                       NaN               NaN                       NaN
# 4                       NaN               NaN                       NaN
# 5                       NaN               NaN                       NaN
# 6                       NaN               NaN                       NaN
# 7                       NaN               NaN                       NaN
# 8                       NaN               NaN                       NaN
# 9                       NaN               NaN                       NaN
#
#   StratificationID3
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
#
# [10 rows x 34 columns]

# %%
df_cdi.tail()
# Out:
#         YearStart  YearEnd LocationAbbr   LocationDesc DataSource     Topic  \
# 523481       2016     2016           US  United States      BRFSS  Diabetes
# 523482       2016     2016           US  United States      BRFSS  Diabetes
# 523483       2016     2016           US  United States      BRFSS  Diabetes
# 523484       2016     2016           US  United States      BRFSS  Diabetes
# 523485       2016     2016           US  United States      BRFSS  Diabetes
#
#                                                  Question Response  \
# 523481  Glycosylated hemoglobin measurement among adul...      NaN
# 523482  Dilated eye examination among adults aged >= 1...      NaN
# 523483  Dilated eye examination among adults aged >= 1...      NaN
# 523484  Dilated eye examination among adults aged >= 1...      NaN
# 523485  Dilated eye examination among adults aged >= 1...      NaN
#
#        DataValueUnit            DataValueType        ...        LocationID  \
# 523481             %  Age-adjusted Prevalence        ...                59
# 523482             %         Crude Prevalence        ...                59
# 523483             %  Age-adjusted Prevalence        ...                59
# 523484             %         Crude Prevalence        ...                59
# 523485             %  Age-adjusted Prevalence        ...                59
#
#         TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 523481      DIA     DIA6_0      AgeAdjPrev                     GENDER
# 523482      DIA     DIA7_0         CrdPrev                     GENDER
# 523483      DIA     DIA7_0      AgeAdjPrev                     GENDER
# 523484      DIA     DIA7_0         CrdPrev                     GENDER
# 523485      DIA     DIA7_0      AgeAdjPrev                     GENDER
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 523481               GENF                       NaN               NaN
# 523482               GENM                       NaN               NaN
# 523483               GENM                       NaN               NaN
# 523484               GENF                       NaN               NaN
# 523485               GENF                       NaN               NaN
#
#        StratificationCategoryID3 StratificationID3
# 523481                       NaN               NaN
# 523482                       NaN               NaN
# 523483                       NaN               NaN
# 523484                       NaN               NaN
# 523485                       NaN               NaN
#
# [5 rows x 34 columns]

# %%
df_cdi[0:2]
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc DataSource    Topic  \
# 0       2016     2016           US  United States      BRFSS  Alcohol
# 1       2016     2016           AL        Alabama      BRFSS  Alcohol
#
#                                             Question Response DataValueUnit  \
# 0  Binge drinking prevalence among adults aged >=...      NaN             %
# 1  Binge drinking prevalence among adults aged >=...      NaN             %
#
#       DataValueType        ...        LocationID  TopicID QuestionID  \
# 0  Crude Prevalence        ...                59      ALC     ALC2_2
# 1  Crude Prevalence        ...                 1      ALC     ALC2_2
#
#   DataValueTypeID  StratificationCategoryID1  StratificationID1  \
# 0         CrdPrev                    OVERALL                OVR
# 1         CrdPrev                    OVERALL                OVR
#
#   StratificationCategoryID2 StratificationID2 StratificationCategoryID3  \
# 0                       NaN               NaN                       NaN
# 1                       NaN               NaN                       NaN
#
#   StratificationID3
# 0               NaN
# 1               NaN
#
# [2 rows x 34 columns]

# %%
df_cdi
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0            2016     2016           US         United States      BRFSS
# 1            2016     2016           AL               Alabama      BRFSS
# 2            2016     2016           AK                Alaska      BRFSS
# 3            2016     2016           AZ               Arizona      BRFSS
# 4            2016     2016           AR              Arkansas      BRFSS
# 5            2016     2016           CA            California      BRFSS
# 6            2016     2016           CO              Colorado      BRFSS
# 7            2016     2016           CT           Connecticut      BRFSS
# 8            2016     2016           DE              Delaware      BRFSS
# 9            2016     2016           DC  District of Columbia      BRFSS
# 10           2016     2016           FL               Florida      BRFSS
# 11           2016     2016           GA               Georgia      BRFSS
# 12           2016     2016           HI                Hawaii      BRFSS
# 13           2016     2016           ID                 Idaho      BRFSS
# 14           2016     2016           IL              Illinois      BRFSS
# 15           2016     2016           IN               Indiana      BRFSS
# 16           2016     2016           IA                  Iowa      BRFSS
# 17           2016     2016           KS                Kansas      BRFSS
# 18           2016     2016           KY              Kentucky      BRFSS
# 19           2016     2016           LA             Louisiana      BRFSS
# 20           2016     2016           ME                 Maine      BRFSS
# 21           2016     2016           MD              Maryland      BRFSS
# 22           2016     2016           MA         Massachusetts      BRFSS
# 23           2016     2016           MI              Michigan      BRFSS
# 24           2016     2016           MN             Minnesota      BRFSS
# 25           2016     2016           MS           Mississippi      BRFSS
# 26           2016     2016           MO              Missouri      BRFSS
# 27           2016     2016           MT               Montana      BRFSS
# 28           2016     2016           NE              Nebraska      BRFSS
# 29           2016     2016           NV                Nevada      BRFSS
# ...           ...      ...          ...                   ...        ...
# 523456       2015     2015           US         United States      BRFSS
# 523457       2011     2011           US         United States      BRFSS
# 523458       2011     2011           US         United States      BRFSS
# 523459       2011     2011           US         United States      BRFSS
# 523460       2011     2011           US         United States      BRFSS
# 523461       2013     2013           US         United States      BRFSS
# 523462       2013     2013           US         United States      BRFSS
# 523463       2016     2016           US         United States      BRFSS
# 523464       2016     2016           US         United States      BRFSS
# 523465       2016     2016           US         United States      BRFSS
# 523466       2016     2016           US         United States      BRFSS
# 523467       2016     2016           US         United States      BRFSS
# 523468       2016     2016           US         United States      BRFSS
# 523469       2016     2016           US         United States      BRFSS
# 523470       2016     2016           US         United States      BRFSS
# 523471       2016     2016           US         United States      BRFSS
# 523472       2016     2016           US         United States      BRFSS
# 523473       2016     2016           US         United States      BRFSS
# 523474       2016     2016           US         United States      BRFSS
# 523475       2016     2016           US         United States      BRFSS
# 523476       2016     2016           US         United States      BRFSS
# 523477       2016     2016           US         United States      BRFSS
# 523478       2016     2016           US         United States      BRFSS
# 523479       2016     2016           US         United States      BRFSS
# 523480       2016     2016           US         United States      BRFSS
# 523481       2016     2016           US         United States      BRFSS
# 523482       2016     2016           US         United States      BRFSS
# 523483       2016     2016           US         United States      BRFSS
# 523484       2016     2016           US         United States      BRFSS
# 523485       2016     2016           US         United States      BRFSS
#
#                                         Topic  \
# 0                                     Alcohol
# 1                                     Alcohol
# 2                                     Alcohol
# 3                                     Alcohol
# 4                                     Alcohol
# 5                                     Alcohol
# 6                                     Alcohol
# 7                                     Alcohol
# 8                                     Alcohol
# 9                                     Alcohol
# 10                                    Alcohol
# 11                                    Alcohol
# 12                                    Alcohol
# 13                                    Alcohol
# 14                                    Alcohol
# 15                                    Alcohol
# 16                                    Alcohol
# 17                                    Alcohol
# 18                                    Alcohol
# 19                                    Alcohol
# 20                                    Alcohol
# 21                                    Alcohol
# 22                                    Alcohol
# 23                                    Alcohol
# 24                                    Alcohol
# 25                                    Alcohol
# 26                                    Alcohol
# 27                                    Alcohol
# 28                                    Alcohol
# 29                                    Alcohol
# ...                                       ...
# 523456                              Arthritis
# 523457                              Arthritis
# 523458                              Arthritis
# 523459                              Arthritis
# 523460                              Arthritis
# 523461                              Arthritis
# 523462                              Arthritis
# 523463  Chronic Obstructive Pulmonary Disease
# 523464  Chronic Obstructive Pulmonary Disease
# 523465  Chronic Obstructive Pulmonary Disease
# 523466  Chronic Obstructive Pulmonary Disease
# 523467  Chronic Obstructive Pulmonary Disease
# 523468  Chronic Obstructive Pulmonary Disease
# 523469  Chronic Obstructive Pulmonary Disease
# 523470                               Diabetes
# 523471                               Diabetes
# 523472                               Diabetes
# 523473                               Diabetes
# 523474                               Diabetes
# 523475                               Diabetes
# 523476                               Diabetes
# 523477                               Diabetes
# 523478                               Diabetes
# 523479                               Diabetes
# 523480                               Diabetes
# 523481                               Diabetes
# 523482                               Diabetes
# 523483                               Diabetes
# 523484                               Diabetes
# 523485                               Diabetes
#
#                                                  Question Response  \
# 0       Binge drinking prevalence among adults aged >=...      NaN
# 1       Binge drinking prevalence among adults aged >=...      NaN
# 2       Binge drinking prevalence among adults aged >=...      NaN
# 3       Binge drinking prevalence among adults aged >=...      NaN
# 4       Binge drinking prevalence among adults aged >=...      NaN
# 5       Binge drinking prevalence among adults aged >=...      NaN
# 6       Binge drinking prevalence among adults aged >=...      NaN
# 7       Binge drinking prevalence among adults aged >=...      NaN
# 8       Binge drinking prevalence among adults aged >=...      NaN
# 9       Binge drinking prevalence among adults aged >=...      NaN
# 10      Binge drinking prevalence among adults aged >=...      NaN
# 11      Binge drinking prevalence among adults aged >=...      NaN
# 12      Binge drinking prevalence among adults aged >=...      NaN
# 13      Binge drinking prevalence among adults aged >=...      NaN
# 14      Binge drinking prevalence among adults aged >=...      NaN
# 15      Binge drinking prevalence among adults aged >=...      NaN
# 16      Binge drinking prevalence among adults aged >=...      NaN
# 17      Binge drinking prevalence among adults aged >=...      NaN
# 18      Binge drinking prevalence among adults aged >=...      NaN
# 19      Binge drinking prevalence among adults aged >=...      NaN
# 20      Binge drinking prevalence among adults aged >=...      NaN
# 21      Binge drinking prevalence among adults aged >=...      NaN
# 22      Binge drinking prevalence among adults aged >=...      NaN
# 23      Binge drinking prevalence among adults aged >=...      NaN
# 24      Binge drinking prevalence among adults aged >=...      NaN
# 25      Binge drinking prevalence among adults aged >=...      NaN
# 26      Binge drinking prevalence among adults aged >=...      NaN
# 27      Binge drinking prevalence among adults aged >=...      NaN
# 28      Binge drinking prevalence among adults aged >=...      NaN
# 29      Binge drinking prevalence among adults aged >=...      NaN
# ...                                                   ...      ...
# 523456  Adults aged >= 18 years with arthritis who hav...      NaN
# 523457  Adults aged >= 18 years with arthritis who hav...      NaN
# 523458  Adults aged >= 18 years with arthritis who hav...      NaN
# 523459  Adults aged >= 18 years with arthritis who hav...      NaN
# 523460  Adults aged >= 18 years with arthritis who hav...      NaN
# 523461  Adults aged >= 18 years with arthritis who hav...      NaN
# 523462  Adults aged >= 18 years with arthritis who hav...      NaN
# 523463  Prevalence of activity limitation among adults...      NaN
# 523464  Prevalence of activity limitation among adults...      NaN
# 523465  Prevalence of activity limitation among adults...      NaN
# 523466  Prevalence of activity limitation among adults...      NaN
# 523467  Prevalence of activity limitation among adults...      NaN
# 523468  Prevalence of activity limitation among adults...      NaN
# 523469  Prevalence of activity limitation among adults...      NaN
# 523470  Adults with diagnosed diabetes aged >= 18 year...      NaN
# 523471  Adults with diagnosed diabetes aged >= 18 year...      NaN
# 523472  Adults with diagnosed diabetes aged >= 18 year...      NaN
# 523473  Adults with diagnosed diabetes aged >= 18 year...      NaN
# 523474  Foot examination among adults aged >= 18 years...      NaN
# 523475  Foot examination among adults aged >= 18 years...      NaN
# 523476  Foot examination among adults aged >= 18 years...      NaN
# 523477  Foot examination among adults aged >= 18 years...      NaN
# 523478  Glycosylated hemoglobin measurement among adul...      NaN
# 523479  Glycosylated hemoglobin measurement among adul...      NaN
# 523480  Glycosylated hemoglobin measurement among adul...      NaN
# 523481  Glycosylated hemoglobin measurement among adul...      NaN
# 523482  Dilated eye examination among adults aged >= 1...      NaN
# 523483  Dilated eye examination among adults aged >= 1...      NaN
# 523484  Dilated eye examination among adults aged >= 1...      NaN
# 523485  Dilated eye examination among adults aged >= 1...      NaN
#
#        DataValueUnit            DataValueType        ...        LocationID  \
# 0                  %         Crude Prevalence        ...                59
# 1                  %         Crude Prevalence        ...                 1
# 2                  %         Crude Prevalence        ...                 2
# 3                  %         Crude Prevalence        ...                 4
# 4                  %         Crude Prevalence        ...                 5
# 5                  %         Crude Prevalence        ...                 6
# 6                  %         Crude Prevalence        ...                 8
# 7                  %         Crude Prevalence        ...                 9
# 8                  %         Crude Prevalence        ...                10
# 9                  %         Crude Prevalence        ...                11
# 10                 %         Crude Prevalence        ...                12
# 11                 %         Crude Prevalence        ...                13
# 12                 %         Crude Prevalence        ...                15
# 13                 %         Crude Prevalence        ...                16
# 14                 %         Crude Prevalence        ...                17
# 15                 %         Crude Prevalence        ...                18
# 16                 %         Crude Prevalence        ...                19
# 17                 %         Crude Prevalence        ...                20
# 18                 %         Crude Prevalence        ...                21
# 19                 %         Crude Prevalence        ...                22
# 20                 %         Crude Prevalence        ...                23
# 21                 %         Crude Prevalence        ...                24
# 22                 %         Crude Prevalence        ...                25
# 23                 %         Crude Prevalence        ...                26
# 24                 %         Crude Prevalence        ...                27
# 25                 %         Crude Prevalence        ...                28
# 26                 %         Crude Prevalence        ...                29
# 27                 %         Crude Prevalence        ...                30
# 28                 %         Crude Prevalence        ...                31
# 29                 %         Crude Prevalence        ...                32
# ...              ...                      ...        ...               ...
# 523456             %         Crude Prevalence        ...                59
# 523457             %  Age-adjusted Prevalence        ...                59
# 523458             %  Age-adjusted Prevalence        ...                59
# 523459             %         Crude Prevalence        ...                59
# 523460             %         Crude Prevalence        ...                59
# 523461             %  Age-adjusted Prevalence        ...                59
# 523462             %  Age-adjusted Prevalence        ...                59
# 523463             %  Age-adjusted Prevalence        ...                59
# 523464             %         Crude Prevalence        ...                59
# 523465             %  Age-adjusted Prevalence        ...                59
# 523466             %         Crude Prevalence        ...                59
# 523467             %  Age-adjusted Prevalence        ...                59
# 523468             %         Crude Prevalence        ...                59
# 523469             %  Age-adjusted Prevalence        ...                59
# 523470             %         Crude Prevalence        ...                59
# 523471             %  Age-adjusted Prevalence        ...                59
# 523472             %         Crude Prevalence        ...                59
# 523473             %  Age-adjusted Prevalence        ...                59
# 523474             %         Crude Prevalence        ...                59
# 523475             %  Age-adjusted Prevalence        ...                59
# 523476             %         Crude Prevalence        ...                59
# 523477             %  Age-adjusted Prevalence        ...                59
# 523478             %         Crude Prevalence        ...                59
# 523479             %  Age-adjusted Prevalence        ...                59
# 523480             %         Crude Prevalence        ...                59
# 523481             %  Age-adjusted Prevalence        ...                59
# 523482             %         Crude Prevalence        ...                59
# 523483             %  Age-adjusted Prevalence        ...                59
# 523484             %         Crude Prevalence        ...                59
# 523485             %  Age-adjusted Prevalence        ...                59
#
#         TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0           ALC     ALC2_2         CrdPrev                    OVERALL
# 1           ALC     ALC2_2         CrdPrev                    OVERALL
# 2           ALC     ALC2_2         CrdPrev                    OVERALL
# 3           ALC     ALC2_2         CrdPrev                    OVERALL
# 4           ALC     ALC2_2         CrdPrev                    OVERALL
# 5           ALC     ALC2_2         CrdPrev                    OVERALL
# 6           ALC     ALC2_2         CrdPrev                    OVERALL
# 7           ALC     ALC2_2         CrdPrev                    OVERALL
# 8           ALC     ALC2_2         CrdPrev                    OVERALL
# 9           ALC     ALC2_2         CrdPrev                    OVERALL
# 10          ALC     ALC2_2         CrdPrev                    OVERALL
# 11          ALC     ALC2_2         CrdPrev                    OVERALL
# 12          ALC     ALC2_2         CrdPrev                    OVERALL
# 13          ALC     ALC2_2         CrdPrev                    OVERALL
# 14          ALC     ALC2_2         CrdPrev                    OVERALL
# 15          ALC     ALC2_2         CrdPrev                    OVERALL
# 16          ALC     ALC2_2         CrdPrev                    OVERALL
# 17          ALC     ALC2_2         CrdPrev                    OVERALL
# 18          ALC     ALC2_2         CrdPrev                    OVERALL
# 19          ALC     ALC2_2         CrdPrev                    OVERALL
# 20          ALC     ALC2_2         CrdPrev                    OVERALL
# 21          ALC     ALC2_2         CrdPrev                    OVERALL
# 22          ALC     ALC2_2         CrdPrev                    OVERALL
# 23          ALC     ALC2_2         CrdPrev                    OVERALL
# 24          ALC     ALC2_2         CrdPrev                    OVERALL
# 25          ALC     ALC2_2         CrdPrev                    OVERALL
# 26          ALC     ALC2_2         CrdPrev                    OVERALL
# 27          ALC     ALC2_2         CrdPrev                    OVERALL
# 28          ALC     ALC2_2         CrdPrev                    OVERALL
# 29          ALC     ALC2_2         CrdPrev                    OVERALL
# ...         ...        ...             ...                        ...
# 523456      ART     ART5_0         CrdPrev                     GENDER
# 523457      ART     ART5_0      AgeAdjPrev                     GENDER
# 523458      ART     ART5_0      AgeAdjPrev                     GENDER
# 523459      ART     ART5_0         CrdPrev                     GENDER
# 523460      ART     ART5_0         CrdPrev                     GENDER
# 523461      ART     ART5_0      AgeAdjPrev                     GENDER
# 523462      ART     ART5_0      AgeAdjPrev                     GENDER
# 523463     COPD    COPD4_0      AgeAdjPrev                     GENDER
# 523464     COPD    COPD4_0         CrdPrev                     GENDER
# 523465     COPD    COPD4_0      AgeAdjPrev                     GENDER
# 523466     COPD  COPD4_0_1         CrdPrev                     GENDER
# 523467     COPD  COPD4_0_1      AgeAdjPrev                     GENDER
# 523468     COPD  COPD4_0_1         CrdPrev                     GENDER
# 523469     COPD  COPD4_0_1      AgeAdjPrev                     GENDER
# 523470      DIA    DIA10_0         CrdPrev                     GENDER
# 523471      DIA    DIA10_0      AgeAdjPrev                     GENDER
# 523472      DIA    DIA10_0         CrdPrev                     GENDER
# 523473      DIA    DIA10_0      AgeAdjPrev                     GENDER
# 523474      DIA     DIA5_0         CrdPrev                     GENDER
# 523475      DIA     DIA5_0      AgeAdjPrev                     GENDER
# 523476      DIA     DIA5_0         CrdPrev                     GENDER
# 523477      DIA     DIA5_0      AgeAdjPrev                     GENDER
# 523478      DIA     DIA6_0         CrdPrev                     GENDER
# 523479      DIA     DIA6_0      AgeAdjPrev                     GENDER
# 523480      DIA     DIA6_0         CrdPrev                     GENDER
# 523481      DIA     DIA6_0      AgeAdjPrev                     GENDER
# 523482      DIA     DIA7_0         CrdPrev                     GENDER
# 523483      DIA     DIA7_0      AgeAdjPrev                     GENDER
# 523484      DIA     DIA7_0         CrdPrev                     GENDER
# 523485      DIA     DIA7_0      AgeAdjPrev                     GENDER
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                     OVR                       NaN               NaN
# 1                     OVR                       NaN               NaN
# 2                     OVR                       NaN               NaN
# 3                     OVR                       NaN               NaN
# 4                     OVR                       NaN               NaN
# 5                     OVR                       NaN               NaN
# 6                     OVR                       NaN               NaN
# 7                     OVR                       NaN               NaN
# 8                     OVR                       NaN               NaN
# 9                     OVR                       NaN               NaN
# 10                    OVR                       NaN               NaN
# 11                    OVR                       NaN               NaN
# 12                    OVR                       NaN               NaN
# 13                    OVR                       NaN               NaN
# 14                    OVR                       NaN               NaN
# 15                    OVR                       NaN               NaN
# 16                    OVR                       NaN               NaN
# 17                    OVR                       NaN               NaN
# 18                    OVR                       NaN               NaN
# 19                    OVR                       NaN               NaN
# 20                    OVR                       NaN               NaN
# 21                    OVR                       NaN               NaN
# 22                    OVR                       NaN               NaN
# 23                    OVR                       NaN               NaN
# 24                    OVR                       NaN               NaN
# 25                    OVR                       NaN               NaN
# 26                    OVR                       NaN               NaN
# 27                    OVR                       NaN               NaN
# 28                    OVR                       NaN               NaN
# 29                    OVR                       NaN               NaN
# ...                   ...                       ...               ...
# 523456               GENM                       NaN               NaN
# 523457               GENF                       NaN               NaN
# 523458               GENM                       NaN               NaN
# 523459               GENF                       NaN               NaN
# 523460               GENM                       NaN               NaN
# 523461               GENF                       NaN               NaN
# 523462               GENM                       NaN               NaN
# 523463               GENM                       NaN               NaN
# 523464               GENF                       NaN               NaN
# 523465               GENF                       NaN               NaN
# 523466               GENM                       NaN               NaN
# 523467               GENM                       NaN               NaN
# 523468               GENF                       NaN               NaN
# 523469               GENF                       NaN               NaN
# 523470               GENM                       NaN               NaN
# 523471               GENM                       NaN               NaN
# 523472               GENF                       NaN               NaN
# 523473               GENF                       NaN               NaN
# 523474               GENM                       NaN               NaN
# 523475               GENM                       NaN               NaN
# 523476               GENF                       NaN               NaN
# 523477               GENF                       NaN               NaN
# 523478               GENM                       NaN               NaN
# 523479               GENM                       NaN               NaN
# 523480               GENF                       NaN               NaN
# 523481               GENF                       NaN               NaN
# 523482               GENM                       NaN               NaN
# 523483               GENM                       NaN               NaN
# 523484               GENF                       NaN               NaN
# 523485               GENF                       NaN               NaN
#
#        StratificationCategoryID3 StratificationID3
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
# 5                            NaN               NaN
# 6                            NaN               NaN
# 7                            NaN               NaN
# 8                            NaN               NaN
# 9                            NaN               NaN
# 10                           NaN               NaN
# 11                           NaN               NaN
# 12                           NaN               NaN
# 13                           NaN               NaN
# 14                           NaN               NaN
# 15                           NaN               NaN
# 16                           NaN               NaN
# 17                           NaN               NaN
# 18                           NaN               NaN
# 19                           NaN               NaN
# 20                           NaN               NaN
# 21                           NaN               NaN
# 22                           NaN               NaN
# 23                           NaN               NaN
# 24                           NaN               NaN
# 25                           NaN               NaN
# 26                           NaN               NaN
# 27                           NaN               NaN
# 28                           NaN               NaN
# 29                           NaN               NaN
# ...                          ...               ...
# 523456                       NaN               NaN
# 523457                       NaN               NaN
# 523458                       NaN               NaN
# 523459                       NaN               NaN
# 523460                       NaN               NaN
# 523461                       NaN               NaN
# 523462                       NaN               NaN
# 523463                       NaN               NaN
# 523464                       NaN               NaN
# 523465                       NaN               NaN
# 523466                       NaN               NaN
# 523467                       NaN               NaN
# 523468                       NaN               NaN
# 523469                       NaN               NaN
# 523470                       NaN               NaN
# 523471                       NaN               NaN
# 523472                       NaN               NaN
# 523473                       NaN               NaN
# 523474                       NaN               NaN
# 523475                       NaN               NaN
# 523476                       NaN               NaN
# 523477                       NaN               NaN
# 523478                       NaN               NaN
# 523479                       NaN               NaN
# 523480                       NaN               NaN
# 523481                       NaN               NaN
# 523482                       NaN               NaN
# 523483                       NaN               NaN
# 523484                       NaN               NaN
# 523485                       NaN               NaN
#
# [523486 rows x 34 columns]

# %%
df_arthritis = df_cdi.loc[df_cdi.Topic == 'Arthritis']

# %%
df_arthritis.shape
# Out:
# (36539, 34)

# %%
df_arthritis.to_csv('Chronic_Disease_Indicators_Arthritis_US.csv')

# %%
df_arth = pd.read_csv('Chronic_Disease_Indicators_Arthritis_US.csv')

# %%
df_arth.shape
# Out:
# (36539, 35)

# %% [markdown]
# ## Make a copy of your working dataset

# %%
df = df_arth.copy()

# %%
df.shape
# Out:
# (36539, 35)

# %%
len(df)
# Out:
# 36539

# %%
len(df.columns)
# Out:
# 35

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc',
#        'DataSource', 'Topic', 'Question', 'Response', 'DataValueUnit',
#        'DataValueType', 'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %% [markdown]
# ## Find the data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36539 entries, 0 to 36538
# Data columns (total 35 columns):
# Unnamed: 0                   36539 non-null int64
# YearStart                    36539 non-null int64
# YearEnd                      36539 non-null int64
# LocationAbbr                 36539 non-null object
# LocationDesc                 36539 non-null object
# DataSource                   36539 non-null object
# Topic                        36539 non-null object
# Question                     36539 non-null object
# Response                     0 non-null float64
# DataValueUnit                36539 non-null object
# DataValueType                36539 non-null object
# DataValue                    25838 non-null float64
# DataValueAlt                 25838 non-null float64
# DataValueFootnoteSymbol      10942 non-null object
# DatavalueFootnote            10942 non-null object
# LowConfidenceLimit           25836 non-null float64
# HighConfidenceLimit          25836 non-null float64
# StratificationCategory1      36539 non-null object
# Stratification1              36539 non-null object
# StratificationCategory2      0 non-null float64
# Stratification2              0 non-null float64
# StratificationCategory3      0 non-null float64
# Stratification3              0 non-null float64
# GeoLocation                  36288 non-null object
# ResponseID                   0 non-null float64
# LocationID                   36539 non-null int64
# TopicID                      36539 non-null object
# QuestionID                   36539 non-null object
# DataValueTypeID              36539 non-null object
# StratificationCategoryID1    36539 non-null object
# StratificationID1            36539 non-null object
# StratificationCategoryID2    0 non-null float64
# StratificationID2            0 non-null float64
# StratificationCategoryID3    0 non-null float64
# StratificationID3            0 non-null float64
# dtypes: float64(14), int64(4), object(17)
# memory usage: 9.8+ MB

# %% [markdown]
# ## Cleaning and preparing your data

# %% [markdown]
# ### Handling Missing Values

# %%
df_sub = df[['YearStart', 'LocationAbbr', 'LocationDesc', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue', 'DatavalueFootnote', 'StratificationCategory1', 'Stratification1', 'GeoLocation']]

# %%
df_sub.head()
# Out:
#    YearStart LocationAbbr   LocationDesc  \
# 0       2016           ME          Maine
# 1       2016           MD       Maryland
# 2       2016           MA  Massachusetts
# 3       2016           MI       Michigan
# 4       2016           US  United States
#
#                                   Question DataValueUnit     DataValueType  \
# 0  Arthritis among adults aged >= 18 years             %  Crude Prevalence
# 1  Arthritis among adults aged >= 18 years             %  Crude Prevalence
# 2  Arthritis among adults aged >= 18 years             %  Crude Prevalence
# 3  Arthritis among adults aged >= 18 years             %  Crude Prevalence
# 4  Arthritis among adults aged >= 18 years             %  Crude Prevalence
#
#    DataValue          DatavalueFootnote StratificationCategory1  \
# 0       33.8                        NaN                 Overall
# 1       24.5                        NaN                 Overall
# 2       25.2                        NaN                 Overall
# 3       32.0                        NaN                 Overall
# 4       25.8  50 States + DC: US Median                 Overall
#
#   Stratification1                               GeoLocation
# 0         Overall  (45.254228894000505, -68.98503133599962)
# 1         Overall   (39.29058096400047, -76.60926011099963)
# 2         Overall   (42.27687047000046, -72.08269067499964)
# 3         Overall    (44.6613195430005, -84.71439026999968)
# 4         Overall                                       NaN

# %%
# df_sub = df_sub.fillna('') # Replaces NaNs with space

# %%
df_sub.dtypes
# Out:
# YearStart                    int64
# LocationAbbr                object
# LocationDesc                object
# Question                    object
# DataValueUnit               object
# DataValueType               object
# DataValue                  float64
# DatavalueFootnote           object
# StratificationCategory1     object
# Stratification1             object
# GeoLocation                 object
# dtype: object

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_sub.describe()
# Out:
#           YearStart     DataValue
# count  36539.000000  25838.000000
# mean    2013.428309     33.364641
# std        1.706477     13.469672
# min     2011.000000      0.000000
# 25%     2012.000000     24.800000
# 50%     2013.000000     32.000000
# 75%     2015.000000     41.200000
# max     2016.000000     91.000000

# %%
df_sub[['LocationDesc', 'StratificationCategory1']].describe()
# Out:
#        LocationDesc StratificationCategory1
# count         36539                   36539
# unique           55                       3
# top     Mississippi          Race/Ethnicity
# freq            672                   22685

# %%
pd.unique(df_sub['Question'])
# Out:
# array(['Arthritis among adults aged >= 18 years',
#        'Arthritis among adults aged >= 18 years who are obese',
#        'Arthritis among adults aged >= 18 years who have diabetes',
#        'Arthritis among adults aged >= 18 years who have heart disease',
#        'Physical inactivity among adults aged >= 18 years with arthritis',
#        'Fair or poor health among adults aged >= 18 years with arthritis',
#        'Activity limitation due to arthritis among adults aged >= 18 years',
#        'Adults aged >= 18 years with arthritis who have taken a class to learn how to manage arthritis symptoms'],
#       dtype=object)

# %%
df_sub['Question'].value_counts()
# Out:
# Arthritis among adults aged >= 18 years who are obese                                                      5225
# Fair or poor health among adults aged >= 18 years with arthritis                                           5220
# Arthritis among adults aged >= 18 years who have heart disease                                             5220
# Physical inactivity among adults aged >= 18 years with arthritis                                           5220
# Arthritis among adults aged >= 18 years                                                                    5220
# Arthritis among adults aged >= 18 years who have diabetes                                                  5220
# Activity limitation due to arthritis among adults aged >= 18 years                                         2610
# Adults aged >= 18 years with arthritis who have taken a class to learn how to manage arthritis symptoms    2604
# Name: Question, dtype: int64

# %%
annual_incidence = df_sub[(df_sub.Question == 'Arthritis among adults aged >= 18 years') &
                         (df_sub.LocationAbbr == 'US') & (df_sub.StratificationCategory1 == "Overall") &
                         (df_sub.DataValueType == 'Crude Prevalence')]

# %%
incidence_race = df_sub[(df_sub.Question == 'Arthritis among adults aged >= 18 years') &
                         (df_sub.LocationAbbr == 'US') & (df_sub.StratificationCategory1 == "Race/Ethnicity")  &
                         (df_sub.DataValueType == 'Age-adjusted Prevalence')]

# %%
incidence_race2 = df_sub[(df_sub.LocationAbbr == 'US') & (df_sub.StratificationCategory1 == "Race/Ethnicity") &
                        (df_sub.DataValueType == 'Age-adjusted Prevalence')]

# %%
incidence_race2
# Out:
#        YearStart LocationAbbr   LocationDesc  \
# 18633       2011           US  United States
# 18635       2011           US  United States
# 18637       2011           US  United States
# 18638       2011           US  United States
# 18640       2011           US  United States
#
#                                                 Question DataValueUnit  \
# 18633  Arthritis among adults aged >= 18 years who ar...             %
# 18635  Arthritis among adults aged >= 18 years who ar...             %
# 18637  Arthritis among adults aged >= 18 years who ar...             %
# 18638  Arthritis among adults aged >= 18 years who ar...             %
# 18640  Arthritis among adults aged >= 18 years who ar...             %
#
#                  DataValueType  DataValue          DatavalueFootnote  \
# 18633  Age-adjusted Prevalence       30.8  50 States + DC: US Median
# 18635  Age-adjusted Prevalence       23.6  50 States + DC: US Median
# 18637  Age-adjusted Prevalence       37.6  50 States + DC: US Median
# 18638  Age-adjusted Prevalence       31.0  50 States + DC: US Median
# 18640  Age-adjusted Prevalence       32.0  50 States + DC: US Median
#
#       StratificationCategory1            Stratification1 GeoLocation
# 18633          Race/Ethnicity        Black, non-Hispanic         NaN
# 18635          Race/Ethnicity                   Hispanic         NaN
# 18637          Race/Ethnicity  Multiracial, non-Hispanic         NaN
# 18638          Race/Ethnicity        Other, non-Hispanic         NaN
# 18640          Race/Ethnicity        White, non-Hispanic         NaN

# %%
incidence_race3 = df_sub[(df_sub.Question == 'Arthritis among adults aged >= 18 years') & (df_sub.StratificationCategory1 == "Race/Ethnicity") &
                        (df_sub.DataValueType == 'Age-adjusted Prevalence')].groupby(['YearStart', 'Stratification1'])['DataValue'].count()

# %%
incidence_race3
# Out:
# YearStart  Stratification1
# 2011       Black, non-Hispanic          40
#            Hispanic                     51
#            Multiracial, non-Hispanic    47
#            Other, non-Hispanic          52
#            White, non-Hispanic          53
# 2012       Black, non-Hispanic          41
#            Hispanic                     53
#            Multiracial, non-Hispanic    49
#            Other, non-Hispanic          52
#            White, non-Hispanic          52
# 2013       Black, non-Hispanic          41
#            Hispanic                     50
#            Multiracial, non-Hispanic    47
#            Other, non-Hispanic          51
#            White, non-Hispanic          52
# 2014       Black, non-Hispanic          41
#            Hispanic                     50
#            Multiracial, non-Hispanic    50
#            Other, non-Hispanic          52
#            White, non-Hispanic          52
# 2015       Black, non-Hispanic          44
#            Hispanic                     49
#            Multiracial, non-Hispanic    51
#            Other, non-Hispanic          52
#            White, non-Hispanic          52
# 2016       Black, non-Hispanic          43
#            Hispanic                     51
#            Multiracial, non-Hispanic    49
#            Other, non-Hispanic          52
#            White, non-Hispanic          53
# Name: DataValue, dtype: int64

# %%
incidence_race4 = df_sub[(df_sub.Question == 'Arthritis among adults aged >= 18 years') & (df_sub.StratificationCategory1 == "Race/Ethnicity") &
                        (df_sub.DataValueType == 'Age-adjusted Prevalence')].groupby(['YearStart', 'Stratification1'])['DataValue'].mean()

# %%
incidence_race4
# Out:
# YearStart  Stratification1
# 2011       Black, non-Hispanic          25.027500
#            Hispanic                     21.219608
#            Multiracial, non-Hispanic    31.414894
#            Other, non-Hispanic          22.832692
#            White, non-Hispanic          23.901887
# 2012       Black, non-Hispanic          26.156098
#            Hispanic                     21.873585
#            Multiracial, non-Hispanic    32.981633
#            Other, non-Hispanic          23.496154
#            White, non-Hispanic          24.861538
# 2013       Black, non-Hispanic          25.802439
#            Hispanic                     21.020000
#            Multiracial, non-Hispanic    33.853191
#            Other, non-Hispanic          21.729412
#            White, non-Hispanic          24.421154
# 2014       Black, non-Hispanic          26.343902
#            Hispanic                     20.454000
#            Multiracial, non-Hispanic    33.248000
#            Other, non-Hispanic          22.846154
#            White, non-Hispanic          24.919231
# 2015       Black, non-Hispanic          24.588636
#            Hispanic                     19.465306
#            Multiracial, non-Hispanic    32.650980
#            Other, non-Hispanic          21.825000
#            White, non-Hispanic          24.367308
# 2016       Black, non-Hispanic          24.795349
#            Hispanic                     19.805882
#            Multiracial, non-Hispanic    33.340816
#            Other, non-Hispanic          21.451923
#            White, non-Hispanic          24.794340
# Name: DataValue, dtype: float64

# %% [markdown]
# ### Matplotlib

# %%
ai = annual_incidence[['YearStart', 'DataValue']].sort_values(by='YearStart')

# %%
ai
# Out:
#        YearStart  DataValue
# 18199       2011       24.4
# 12982       2012       25.7
# 30379       2013       25.3
# 25158       2014       26.0
# 6025        2015       25.3
# 4           2016       25.8

# %%
ai.set_index('YearStart')['DataValue'].plot.bar()

# %%
gender_incidence = df_sub[(df_sub.Question == 'Arthritis among adults aged >= 18 years') &
                        (df_sub.LocationAbbr == 'US') &
                        (df_sub.DataValueType == 'Crude Prevalence')].groupby(['YearStart', 'Stratification1'])['DataValue'].mean()

# %%
gender_incidence
# Out:
# YearStart  Stratification1
# 2011       Female             28.2
#            Male               20.7
#            Overall            24.4
# 2012       Female             28.9
#            Male               22.4
#            Overall            25.7
# 2013       Female             29.0
#            Male               21.6
#            Overall            25.3
# 2014       Female             29.9
#            Male               22.4
#            Overall            26.0
# 2015       Female             29.0
#            Male               22.0
#            Overall            25.3
# 2016       Female             29.0
#            Male               22.1
#            Overall            25.8
# Name: DataValue, dtype: float64

# %%
gif = gender_incidence.unstack()

# %%
gif.plot.bar()

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

# %%
sns.set()

# %%
sns.set_palette(sns.color_palette("Set2", 10))
